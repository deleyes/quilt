# %% [markdown]
# # Quilt3 quick start
# `quilt3` is a Python library that lets you create versioned datasets in S3 with a few simple commands.
#
# A *quilt package* is a collection of files with an immutable version hash. Packages can be of any size and can contain any kind of data. To learn more, read the [Quilt mental model](https://docs.quiltdata.com/v/master/mentalmodel) in our docs for more.
#
# You can use `quilt3` on the command-line or in Python.
#
# The are three key commands in `quilt3`:
# * `push` stores data in a *registry* (usually an S3 bucket)
# * `browse` lets you interact with a remote data package without downloading all of the data
# * `install` downloads the data to the host
#
#
# ## Pre-requisites
# To run this notebook you'll need the following:
# 1. Python 3.6 or higher
# 1. An AWS account, and access to an S3 bucket
# 1. [AWS Credentials](https://docs.aws.amazon.com/cli/latest/userguide/cli-chap-configure.html) on your machine
# 1. Optional: a Python environment
# 1. `pandas`

# %% [markdown]
# ## Installation
# If you haven't already switch to a clean and optionally activate a Python environment.
#
# ```sh
# cd YOUR_CLEAN_DIR
# . activate YOUR_ENV
# pip install pandas
# ```

# %%
! pip install 'quilt3[pyarrow]'
# Out:
# zsh:1: command not found: pip

# %% [markdown]
# ## Install a data package
# Let's get some data. We could also do this in Python. But for simple tasks I find the CLI more convenient.

# %%
! quilt3 install examples/hurdat2 --registry s3://quilt-example --dest data
# Out:
# zsh:1: command not found: quilt3

# %% [markdown]
# The above command brought the latest version of the package `examples/hurdat2` to our local machine (it created the data directory for us as well, as specified with `--dest`). The registry is simply an S3 bucket that hosts our data. Quilt can use any S3 bucket as a data repository.

# %%
# !ls data
# Out:
# Atlantic-HURDAT2.parquet external
# README.md                quilt_summarize.json

# %% [markdown]
# These are standard files that we can interact with. For example:

# %%
! wc -l data/README.md
# Out:
#       22 data/README.md

# %%
! ls -R
# Out:
# QuickStart.ipynb data             env
#
# ./data:
# Atlantic-HURDAT2.parquet external
# README.md                quilt_summarize.json
#
# ./data/external:
# hurdat2-1851-2020-052921.txt hurdat2-format-nov2019.pdf
#
# ./env:
# bin        etc        include    lib        pyvenv.cfg share
#
# ./env/bin:
# Activate.ps1         jupyter-events       numpy-config
# __pycache__          jupyter-execute      pip
# activate             jupyter-kernel       pip3
# activate.csh         jupyter-kernelspec   pip3.10
# activate.fish        jupyter-lab          pybabel
# f2py                 jupyter-labextension pygmentize
# httpx                jupyter-labhub       pyjson5
# ipython              jupyter-migrate      python
# ipython3             jupyter-nbconvert    python3
# jlpm                 jupyter-notebook     python3.10
# jp.py                jupyter-qtconsole    qtpy
# jsonpointer          jupyter-run          quilt3
# jsonschema           jupyter-server       send2trash
# jupyter              jupyter-troubleshoot tqdm
# jupyter-console      jupyter-trust        wsdump
# jupyter-dejavu       normalizer
#
# ./env/bin/__pycache__:
# jp.cpython-310.pyc
#
# ./env/etc:
# jupyter
#
# ./env/etc/jupyter:
# jupyter_notebook_config.d labconfig
# jupyter_server_config.d   nbconfig
#
# ./env/etc/jupyter/jupyter_notebook_config.d:
# jupyterlab.json
#
# ./env/etc/jupyter/jupyter_server_config.d:
# jupyter-lsp-jupyter-server.json notebook.json
# jupyter_server_terminals.json   notebook_shim.json
# jupyterlab.json
#
# ./env/etc/jupyter/labconfig:
# page_config.json
#
# ./env/etc/jupyter/nbconfig:
# notebook.d
#
# ./env/etc/jupyter/nbconfig/notebook.d:
# widgetsnbextension.json
#
# ./env/include:
#
# ./env/lib:
# python3.10
#
# ./env/lib/python3.10:
# site-packages
#
# ./env/lib/python3.10/site-packages:
# Babel-2.15.0.dist-info
# IPython
# MarkupSafe-2.1.5.dist-info
# PyYAML-6.0.1.dist-info
# QtPy-2.4.1.dist-info
# Send2Trash-1.8.3.dist-info
# __pycache__
# _argon2_cffi_bindings
# _cffi_backend.cpython-310-darwin.so
# _distutils_hack
# _yaml
# anyio
# anyio-4.4.0.dist-info
# appnope
# appnope-0.1.4.dist-info
# argon2
# argon2_cffi-23.1.0.dist-info
# argon2_cffi_bindings-21.2.0.dist-info
# arrow
# arrow-1.3.0.dist-info
# asttokens
# asttokens-2.4.1.dist-info
# async_lru
# async_lru-2.0.4.dist-info
# attr
# attrs
# attrs-23.2.0.dist-info
# aws_requests_auth
# aws_requests_auth-0.4.3.dist-info
# babel
# beautifulsoup4-4.12.3.dist-info
# bleach
# bleach-6.1.0.dist-info
# boto3
# boto3-1.34.139.dist-info
# botocore
# botocore-1.34.139.dist-info
# bs4
# certifi
# certifi-2024.7.4.dist-info
# cffi
# cffi-1.16.0.dist-info
# charset_normalizer
# charset_normalizer-3.3.2.dist-info
# comm
# comm-0.2.2.dist-info
# dateutil
# dateutil-stubs
# debugpy
# debugpy-1.8.2.dist-info
# decorator-5.1.1.dist-info
# decorator.py
# defusedxml
# defusedxml-0.7.1.dist-info
# distutils-precedence.pth
# exceptiongroup
# exceptiongroup-1.2.1.dist-info
# executing
# executing-2.0.1.dist-info
# fastjsonschema
# fastjsonschema-2.20.0.dist-info
# fqdn
# fqdn-1.5.1.dist-info
# h11
# h11-0.14.0.dist-info
# httpcore
# httpcore-1.0.5.dist-info
# httpx
# httpx-0.27.0.dist-info
# idna
# idna-3.7.dist-info
# ipykernel
# ipykernel-6.29.5.dist-info
# ipykernel_launcher.py
# ipython-8.26.0.dist-info
# ipywidgets
# ipywidgets-8.1.3.dist-info
# isoduration
# isoduration-20.11.0.dist-info
# jedi
# jedi-0.19.1.dist-info
# jinja2
# jinja2-3.1.4.dist-info
# jmespath
# jmespath-1.0.1.dist-info
# json5
# json5-0.9.25.dist-info
# jsonlines
# jsonlines-1.2.0.dist-info
# jsonpointer-3.0.0.dist-info
# jsonpointer.py
# jsonschema
# jsonschema-4.22.0.dist-info
# jsonschema_specifications
# jsonschema_specifications-2023.12.1.dist-info
# jupyter-1.0.0.dist-info
# jupyter.py
# jupyter_client
# jupyter_client-8.6.2.dist-info
# jupyter_console
# jupyter_console-6.6.3.dist-info
# jupyter_core
# jupyter_core-5.7.2.dist-info
# jupyter_events
# jupyter_events-0.10.0.dist-info
# jupyter_lsp
# jupyter_lsp-2.2.5.dist-info
# jupyter_server
# jupyter_server-2.14.1.dist-info
# jupyter_server_terminals
# jupyter_server_terminals-0.5.3.dist-info
# jupyterlab
# jupyterlab-4.2.3.dist-info
# jupyterlab_pygments
# jupyterlab_pygments-0.3.0.dist-info
# jupyterlab_server
# jupyterlab_server-2.27.2.dist-info
# jupyterlab_widgets
# jupyterlab_widgets-3.0.11.dist-info
# markupsafe
# matplotlib_inline
# matplotlib_inline-0.1.7.dist-info
# mistune
# mistune-3.0.2.dist-info
# nbclient
# nbclient-0.10.0.dist-info
# nbconvert
# nbconvert-7.16.4.dist-info
# nbformat
# nbformat-5.10.4.dist-info
# nest_asyncio-1.6.0.dist-info
# nest_asyncio.py
# notebook
# notebook-7.2.1.dist-info
# notebook_shim
# notebook_shim-0.2.4.dist-info
# numpy
# numpy-2.0.0.dist-info
# overrides
# overrides-7.7.0.dist-info
# packaging
# packaging-24.1.dist-info
# pandas
# pandas-2.2.2.dist-info
# pandocfilters-1.5.1.dist-info
# pandocfilters.py
# parso
# parso-0.8.4.dist-info
# pexpect
# pexpect-4.9.0.dist-info
# pip
# pip-22.3.1.dist-info
# pkg_resources
# platformdirs
# platformdirs-4.2.2.dist-info
# prometheus_client
# prometheus_client-0.20.0.dist-info
# prompt_toolkit
# prompt_toolkit-3.0.47.dist-info
# psutil
# psutil-6.0.0.dist-info
# ptyprocess
# ptyprocess-0.7.0.dist-info
# pure_eval
# pure_eval-0.2.2.dist-info
# pyarrow
# pyarrow-16.1.0.dist-info
# pycparser
# pycparser-2.22.dist-info
# pygments
# pygments-2.18.0.dist-info
# python_dateutil-2.9.0.post0.dist-info
# python_json_logger-2.0.7.dist-info
# pythonjsonlogger
# pytz
# pytz-2024.1.dist-info
# pyzmq-26.0.3.dist-info
# qtconsole
# qtconsole-5.5.2.dist-info
# qtpy
# quilt3
# quilt3-5.4.0.dist-info
# referencing
# referencing-0.35.1.dist-info
# requests
# requests-2.32.3.dist-info
# requests_futures
# requests_futures-1.0.0.dist-info
# rfc3339_validator-0.1.4.dist-info
# rfc3339_validator.py
# rfc3986_validator-0.1.1.dist-info
# rfc3986_validator.py
# rpds
# rpds_py-0.18.1.dist-info
# s3transfer
# s3transfer-0.10.2.dist-info
# send2trash
# setuptools
# setuptools-65.5.0.dist-info
# six-1.16.0.dist-info
# six.py
# sniffio
# sniffio-1.3.1.dist-info
# soupsieve
# soupsieve-2.5.dist-info
# stack_data
# stack_data-0.6.3.dist-info
# tenacity
# tenacity-8.4.2.dist-info
# terminado
# terminado-0.18.1.dist-info
# tinycss2
# tinycss2-1.3.0.dist-info
# tomli
# tomli-2.0.1.dist-info
# tornado
# tornado-6.4.1.dist-info
# tqdm
# tqdm-4.66.4.dist-info
# traitlets
# traitlets-5.14.3.dist-info
# types_python_dateutil-2.9.0.20240316.dist-info
# typing_extensions-4.12.2.dist-info
# typing_extensions.py
# tzdata
# tzdata-2024.1.dist-info
# uri_template
# uri_template-1.3.0.dist-info
# urllib3
# urllib3-2.2.2.dist-info
# wcwidth
# wcwidth-0.2.13.dist-info
# webcolors
# webcolors-24.6.0.dist-info
# webencodings
# webencodings-0.5.1.dist-info
# websocket
# websocket_client-1.8.0.dist-info
# widgetsnbextension
# widgetsnbextension-4.0.11.dist-info
# yaml
# zmq
#
# ./env/lib/python3.10/site-packages/Babel-2.15.0.dist-info:
# INSTALLER        METADATA         WHEEL            top_level.txt
# LICENSE          RECORD           entry_points.txt
#
# ./env/lib/python3.10/site-packages/IPython:
# __init__.py   consoleapp.py external      sphinxext
# __main__.py   core          lib           terminal
# __pycache__   display.py    paths.py      testing
# conftest.py   extensions    py.typed      utils
#
# ./env/lib/python3.10/site-packages/IPython/__pycache__:
# __init__.cpython-310.pyc   consoleapp.cpython-310.pyc
# __main__.cpython-310.pyc   display.cpython-310.pyc
# conftest.cpython-310.pyc   paths.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/core:
# __init__.py          events.py            magics
# __pycache__          excolors.py          oinspect.py
# alias.py             extensions.py        page.py
# application.py       formatters.py        payload.py
# async_helpers.py     getipython.py        payloadpage.py
# autocall.py          guarded_eval.py      prefilter.py
# builtin_trap.py      history.py           profile
# compilerop.py        historyapp.py        profileapp.py
# completer.py         hooks.py             profiledir.py
# completerlib.py      inputsplitter.py     prompts.py
# crashhandler.py      inputtransformer.py  pylabtools.py
# debugger.py          inputtransformer2.py release.py
# display.py           interactiveshell.py  shellapp.py
# display_functions.py latex_symbols.py     splitinput.py
# display_trap.py      logger.py            tests
# displayhook.py       macro.py             ultratb.py
# displaypub.py        magic.py             usage.py
# error.py             magic_arguments.py
#
# ./env/lib/python3.10/site-packages/IPython/core/__pycache__:
# __init__.cpython-310.pyc          hooks.cpython-310.pyc
# alias.cpython-310.pyc             inputsplitter.cpython-310.pyc
# application.cpython-310.pyc       inputtransformer.cpython-310.pyc
# async_helpers.cpython-310.pyc     inputtransformer2.cpython-310.pyc
# autocall.cpython-310.pyc          interactiveshell.cpython-310.pyc
# builtin_trap.cpython-310.pyc      latex_symbols.cpython-310.pyc
# compilerop.cpython-310.pyc        logger.cpython-310.pyc
# completer.cpython-310.pyc         macro.cpython-310.pyc
# completerlib.cpython-310.pyc      magic.cpython-310.pyc
# crashhandler.cpython-310.pyc      magic_arguments.cpython-310.pyc
# debugger.cpython-310.pyc          oinspect.cpython-310.pyc
# display.cpython-310.pyc           page.cpython-310.pyc
# display_functions.cpython-310.pyc payload.cpython-310.pyc
# display_trap.cpython-310.pyc      payloadpage.cpython-310.pyc
# displayhook.cpython-310.pyc       prefilter.cpython-310.pyc
# displaypub.cpython-310.pyc        profileapp.cpython-310.pyc
# error.cpython-310.pyc             profiledir.cpython-310.pyc
# events.cpython-310.pyc            prompts.cpython-310.pyc
# excolors.cpython-310.pyc          pylabtools.cpython-310.pyc
# extensions.cpython-310.pyc        release.cpython-310.pyc
# formatters.cpython-310.pyc        shellapp.cpython-310.pyc
# getipython.cpython-310.pyc        splitinput.cpython-310.pyc
# guarded_eval.cpython-310.pyc      ultratb.cpython-310.pyc
# history.cpython-310.pyc           usage.cpython-310.pyc
# historyapp.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/core/magics:
# __init__.py  auto.py      config.py    extension.py namespace.py pylab.py
# __pycache__  basic.py     display.py   history.py   osm.py       script.py
# ast_mod.py   code.py      execution.py logging.py   packaging.py
#
# ./env/lib/python3.10/site-packages/IPython/core/magics/__pycache__:
# __init__.cpython-310.pyc  display.cpython-310.pyc   osm.cpython-310.pyc
# ast_mod.cpython-310.pyc   execution.cpython-310.pyc packaging.cpython-310.pyc
# auto.cpython-310.pyc      extension.cpython-310.pyc pylab.cpython-310.pyc
# basic.cpython-310.pyc     history.cpython-310.pyc   script.cpython-310.pyc
# code.cpython-310.pyc      logging.cpython-310.pyc
# config.cpython-310.pyc    namespace.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/core/profile:
# README_STARTUP
#
# ./env/lib/python3.10/site-packages/IPython/core/tests:
# 2x2.jpg                        test_guarded_eval.py
# 2x2.png                        test_handlers.py
# __init__.py                    test_history.py
# __pycache__                    test_hooks.py
# bad_all.py                     test_imports.py
# daft_extension                 test_inputsplitter.py
# nonascii.py                    test_inputtransformer.py
# nonascii2.py                   test_inputtransformer2.py
# print_argv.py                  test_inputtransformer2_line.py
# refbug.py                      test_interactiveshell.py
# simpleerr.py                   test_iplib.py
# tclass.py                      test_logger.py
# test_alias.py                  test_magic.py
# test_application.py            test_magic_arguments.py
# test_async_helpers.py          test_magic_terminal.py
# test_autocall.py               test_oinspect.py
# test_compilerop.py             test_page.py
# test_completer.py              test_paths.py
# test_completerlib.py           test_prefilter.py
# test_debugger.py               test_profile.py
# test_display.py                test_prompts.py
# test_displayhook.py            test_pylabtools.py
# test_events.py                 test_run.py
# test_exceptiongroup_tb.py      test_shellapp.py
# test_extension.py              test_splitinput.py
# test_formatters.py             test_ultratb.py
#
# ./env/lib/python3.10/site-packages/IPython/core/tests/__pycache__:
# __init__.cpython-310.pyc
# bad_all.cpython-310.pyc
# nonascii.cpython-310.pyc
# nonascii2.cpython-310.pyc
# print_argv.cpython-310.pyc
# refbug.cpython-310.pyc
# simpleerr.cpython-310.pyc
# tclass.cpython-310.pyc
# test_alias.cpython-310.pyc
# test_application.cpython-310.pyc
# test_async_helpers.cpython-310.pyc
# test_autocall.cpython-310.pyc
# test_compilerop.cpython-310.pyc
# test_completer.cpython-310.pyc
# test_completerlib.cpython-310.pyc
# test_debugger.cpython-310.pyc
# test_display.cpython-310.pyc
# test_displayhook.cpython-310.pyc
# test_events.cpython-310.pyc
# test_exceptiongroup_tb.cpython-310.pyc
# test_extension.cpython-310.pyc
# test_formatters.cpython-310.pyc
# test_guarded_eval.cpython-310.pyc
# test_handlers.cpython-310.pyc
# test_history.cpython-310.pyc
# test_hooks.cpython-310.pyc
# test_imports.cpython-310.pyc
# test_inputsplitter.cpython-310.pyc
# test_inputtransformer.cpython-310.pyc
# test_inputtransformer2.cpython-310.pyc
# test_inputtransformer2_line.cpython-310.pyc
# test_interactiveshell.cpython-310.pyc
# test_iplib.cpython-310.pyc
# test_logger.cpython-310.pyc
# test_magic.cpython-310.pyc
# test_magic_arguments.cpython-310.pyc
# test_magic_terminal.cpython-310.pyc
# test_oinspect.cpython-310.pyc
# test_page.cpython-310.pyc
# test_paths.cpython-310.pyc
# test_prefilter.cpython-310.pyc
# test_profile.cpython-310.pyc
# test_prompts.cpython-310.pyc
# test_pylabtools.cpython-310.pyc
# test_run.cpython-310.pyc
# test_shellapp.cpython-310.pyc
# test_splitinput.cpython-310.pyc
# test_ultratb.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/core/tests/daft_extension:
# __pycache__       daft_extension.py
#
# ./env/lib/python3.10/site-packages/IPython/core/tests/daft_extension/__pycache__:
# daft_extension.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/extensions:
# __init__.py   __pycache__   autoreload.py storemagic.py tests
#
# ./env/lib/python3.10/site-packages/IPython/extensions/__pycache__:
# __init__.cpython-310.pyc   storemagic.cpython-310.pyc
# autoreload.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/extensions/tests:
# __init__.py        __pycache__        test_autoreload.py test_storemagic.py
#
# ./env/lib/python3.10/site-packages/IPython/extensions/tests/__pycache__:
# __init__.cpython-310.pyc        test_storemagic.cpython-310.pyc
# test_autoreload.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/external:
# __init__.py      qt_for_kernel.py tests
# __pycache__      qt_loaders.py
#
# ./env/lib/python3.10/site-packages/IPython/external/__pycache__:
# __init__.cpython-310.pyc      qt_loaders.cpython-310.pyc
# qt_for_kernel.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/external/tests:
# __init__.py        __pycache__        test_qt_loaders.py
#
# ./env/lib/python3.10/site-packages/IPython/external/tests/__pycache__:
# __init__.cpython-310.pyc        test_qt_loaders.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/lib:
# __init__.py       deepreload.py     guisupport.py     tests
# __pycache__       demo.py           latextools.py
# backgroundjobs.py display.py        lexers.py
# clipboard.py      editorhooks.py    pretty.py
#
# ./env/lib/python3.10/site-packages/IPython/lib/__pycache__:
# __init__.cpython-310.pyc       editorhooks.cpython-310.pyc
# backgroundjobs.cpython-310.pyc guisupport.cpython-310.pyc
# clipboard.cpython-310.pyc      latextools.cpython-310.pyc
# deepreload.cpython-310.pyc     lexers.cpython-310.pyc
# demo.cpython-310.pyc           pretty.cpython-310.pyc
# display.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/lib/tests:
# __init__.py            test_deepreload.py     test_lexers.py
# __pycache__            test_display.py        test_pretty.py
# test.wav               test_editorhooks.py    test_pygments.py
# test_backgroundjobs.py test_imports.py
# test_clipboard.py      test_latextools.py
#
# ./env/lib/python3.10/site-packages/IPython/lib/tests/__pycache__:
# __init__.cpython-310.pyc            test_imports.cpython-310.pyc
# test_backgroundjobs.cpython-310.pyc test_latextools.cpython-310.pyc
# test_clipboard.cpython-310.pyc      test_lexers.cpython-310.pyc
# test_deepreload.cpython-310.pyc     test_pretty.cpython-310.pyc
# test_display.cpython-310.pyc        test_pygments.cpython-310.pyc
# test_editorhooks.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/sphinxext:
# __init__.py                     ipython_console_highlighting.py
# __pycache__                     ipython_directive.py
# custom_doctests.py
#
# ./env/lib/python3.10/site-packages/IPython/sphinxext/__pycache__:
# __init__.cpython-310.pyc
# custom_doctests.cpython-310.pyc
# ipython_console_highlighting.cpython-310.pyc
# ipython_directive.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/terminal:
# __init__.py         embed.py            prompts.py          tests
# __pycache__         interactiveshell.py pt_inputhooks
# console.py          ipapp.py            ptutils.py
# debugger.py         magics.py           shortcuts
#
# ./env/lib/python3.10/site-packages/IPython/terminal/__pycache__:
# __init__.cpython-310.pyc         ipapp.cpython-310.pyc
# console.cpython-310.pyc          magics.cpython-310.pyc
# debugger.cpython-310.pyc         prompts.cpython-310.pyc
# embed.cpython-310.pyc            ptutils.cpython-310.pyc
# interactiveshell.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks:
# __init__.py asyncio.py  gtk.py      gtk4.py     pyglet.py   tk.py
# __pycache__ glut.py     gtk3.py     osx.py      qt.py       wx.py
#
# ./env/lib/python3.10/site-packages/IPython/terminal/pt_inputhooks/__pycache__:
# __init__.cpython-310.pyc gtk3.cpython-310.pyc     qt.cpython-310.pyc
# asyncio.cpython-310.pyc  gtk4.cpython-310.pyc     tk.cpython-310.pyc
# glut.cpython-310.pyc     osx.cpython-310.pyc      wx.cpython-310.pyc
# gtk.cpython-310.pyc      pyglet.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/terminal/shortcuts:
# __init__.py     __pycache__     auto_match.py   auto_suggest.py filters.py
#
# ./env/lib/python3.10/site-packages/IPython/terminal/shortcuts/__pycache__:
# __init__.cpython-310.pyc     auto_suggest.cpython-310.pyc
# auto_match.cpython-310.pyc   filters.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/terminal/tests:
# __init__.py             test_embed.py           test_pt_inputhooks.py
# __pycache__             test_help.py            test_shortcuts.py
# test_debug_magic.py     test_interactivshell.py
#
# ./env/lib/python3.10/site-packages/IPython/terminal/tests/__pycache__:
# __init__.cpython-310.pyc             test_interactivshell.cpython-310.pyc
# test_debug_magic.cpython-310.pyc     test_pt_inputhooks.cpython-310.pyc
# test_embed.cpython-310.pyc           test_shortcuts.cpython-310.pyc
# test_help.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/testing:
# __init__.py    decorators.py  ipunittest.py  skipdoctest.py tools.py
# __pycache__    globalipapp.py plugin         tests
#
# ./env/lib/python3.10/site-packages/IPython/testing/__pycache__:
# __init__.cpython-310.pyc    ipunittest.cpython-310.pyc
# decorators.cpython-310.pyc  skipdoctest.cpython-310.pyc
# globalipapp.cpython-310.pyc tools.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/testing/plugin:
# README.txt          ipdoctest.py        simplevars.py       test_ipdoctest.py
# __init__.py         pytest_ipdoctest.py test_combo.txt      test_refs.py
# __pycache__         setup.py            test_example.txt
# dtexample.py        simple.py           test_exampleip.txt
#
# ./env/lib/python3.10/site-packages/IPython/testing/plugin/__pycache__:
# __init__.cpython-310.pyc         simple.cpython-310.pyc
# dtexample.cpython-310.pyc        simplevars.cpython-310.pyc
# ipdoctest.cpython-310.pyc        test_ipdoctest.cpython-310.pyc
# pytest_ipdoctest.cpython-310.pyc test_refs.cpython-310.pyc
# setup.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/testing/tests:
# __init__.py        test_decorators.py test_tools.py
# __pycache__        test_ipunittest.py
#
# ./env/lib/python3.10/site-packages/IPython/testing/tests/__pycache__:
# __init__.cpython-310.pyc        test_ipunittest.cpython-310.pyc
# test_decorators.cpython-310.pyc test_tools.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/utils:
# PyColorize.py                jsonutil.py
# __init__.py                  localinterfaces.py
# __pycache__                  log.py
# _process_cli.py              module_paths.py
# _process_common.py           openpy.py
# _process_emscripten.py       path.py
# _process_posix.py            process.py
# _process_win32.py            py3compat.py
# _process_win32_controller.py sentinel.py
# _sysinfo.py                  shimmodule.py
# capture.py                   signatures.py
# colorable.py                 strdispatch.py
# coloransi.py                 sysinfo.py
# contexts.py                  syspathcontext.py
# daemonize.py                 tempdir.py
# data.py                      terminal.py
# decorators.py                tests
# dir2.py                      text.py
# docs.py                      timing.py
# encoding.py                  tokenutil.py
# eventful.py                  traitlets.py
# frame.py                     tz.py
# generics.py                  ulinecache.py
# importstring.py              version.py
# io.py                        wildcard.py
# ipstruct.py
#
# ./env/lib/python3.10/site-packages/IPython/utils/__pycache__:
# PyColorize.cpython-310.pyc
# __init__.cpython-310.pyc
# _process_cli.cpython-310.pyc
# _process_common.cpython-310.pyc
# _process_emscripten.cpython-310.pyc
# _process_posix.cpython-310.pyc
# _process_win32.cpython-310.pyc
# _process_win32_controller.cpython-310.pyc
# _sysinfo.cpython-310.pyc
# capture.cpython-310.pyc
# colorable.cpython-310.pyc
# coloransi.cpython-310.pyc
# contexts.cpython-310.pyc
# daemonize.cpython-310.pyc
# data.cpython-310.pyc
# decorators.cpython-310.pyc
# dir2.cpython-310.pyc
# docs.cpython-310.pyc
# encoding.cpython-310.pyc
# eventful.cpython-310.pyc
# frame.cpython-310.pyc
# generics.cpython-310.pyc
# importstring.cpython-310.pyc
# io.cpython-310.pyc
# ipstruct.cpython-310.pyc
# jsonutil.cpython-310.pyc
# localinterfaces.cpython-310.pyc
# log.cpython-310.pyc
# module_paths.cpython-310.pyc
# openpy.cpython-310.pyc
# path.cpython-310.pyc
# process.cpython-310.pyc
# py3compat.cpython-310.pyc
# sentinel.cpython-310.pyc
# shimmodule.cpython-310.pyc
# signatures.cpython-310.pyc
# strdispatch.cpython-310.pyc
# sysinfo.cpython-310.pyc
# syspathcontext.cpython-310.pyc
# tempdir.cpython-310.pyc
# terminal.cpython-310.pyc
# text.cpython-310.pyc
# timing.cpython-310.pyc
# tokenutil.cpython-310.pyc
# traitlets.cpython-310.pyc
# tz.cpython-310.pyc
# ulinecache.cpython-310.pyc
# version.cpython-310.pyc
# wildcard.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/IPython/utils/tests:
# __init__.py          test_importstring.py test_shimmodule.py
# __pycache__          test_io.py           test_sysinfo.py
# test_capture.py      test_module_paths.py test_tempdir.py
# test_decorators.py   test_openpy.py       test_text.py
# test_deprecated.py   test_path.py         test_tokenutil.py
# test_dir2.py         test_process.py      test_wildcard.py
# test_imports.py      test_pycolorize.py
#
# ./env/lib/python3.10/site-packages/IPython/utils/tests/__pycache__:
# __init__.cpython-310.pyc          test_path.cpython-310.pyc
# test_capture.cpython-310.pyc      test_process.cpython-310.pyc
# test_decorators.cpython-310.pyc   test_pycolorize.cpython-310.pyc
# test_deprecated.cpython-310.pyc   test_shimmodule.cpython-310.pyc
# test_dir2.cpython-310.pyc         test_sysinfo.cpython-310.pyc
# test_imports.cpython-310.pyc      test_tempdir.cpython-310.pyc
# test_importstring.cpython-310.pyc test_text.cpython-310.pyc
# test_io.cpython-310.pyc           test_tokenutil.cpython-310.pyc
# test_module_paths.cpython-310.pyc test_wildcard.cpython-310.pyc
# test_openpy.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/MarkupSafe-2.1.5.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE.rst   RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/PyYAML-6.0.1.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/QtPy-2.4.1.dist-info:
# AUTHORS.md       LICENSE.txt      RECORD           entry_points.txt
# INSTALLER        METADATA         WHEEL            top_level.txt
#
# ./env/lib/python3.10/site-packages/Send2Trash-1.8.3.dist-info:
# INSTALLER        METADATA         WHEEL            top_level.txt
# LICENSE          RECORD           entry_points.txt
#
# ./env/lib/python3.10/site-packages/__pycache__:
# decorator.cpython-310.pyc          pandocfilters.cpython-310.pyc
# ipykernel_launcher.cpython-310.pyc rfc3339_validator.cpython-310.pyc
# jsonpointer.cpython-310.pyc        rfc3986_validator.cpython-310.pyc
# jupyter.cpython-310.pyc            six.cpython-310.pyc
# nest_asyncio.cpython-310.pyc       typing_extensions.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/_argon2_cffi_bindings:
# __init__.py   __pycache__   _ffi.abi3.so  _ffi_build.py
#
# ./env/lib/python3.10/site-packages/_argon2_cffi_bindings/__pycache__:
# __init__.cpython-310.pyc   _ffi_build.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/_distutils_hack:
# __init__.py __pycache__ override.py
#
# ./env/lib/python3.10/site-packages/_distutils_hack/__pycache__:
# __init__.cpython-310.pyc override.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/_yaml:
# __init__.py __pycache__
#
# ./env/lib/python3.10/site-packages/_yaml/__pycache__:
# __init__.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio:
# __init__.py      _core            lowlevel.py      streams
# __pycache__      abc              py.typed         to_process.py
# _backends        from_thread.py   pytest_plugin.py to_thread.py
#
# ./env/lib/python3.10/site-packages/anyio/__pycache__:
# __init__.cpython-310.pyc      pytest_plugin.cpython-310.pyc
# from_thread.cpython-310.pyc   to_process.cpython-310.pyc
# lowlevel.cpython-310.pyc      to_thread.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio/_backends:
# __init__.py __pycache__ _asyncio.py _trio.py
#
# ./env/lib/python3.10/site-packages/anyio/_backends/__pycache__:
# __init__.cpython-310.pyc _asyncio.cpython-310.pyc _trio.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio/_core:
# __init__.py         _fileio.py          _streams.py         _testing.py
# __pycache__         _resources.py       _subprocesses.py    _typedattr.py
# _eventloop.py       _signals.py         _synchronization.py
# _exceptions.py      _sockets.py         _tasks.py
#
# ./env/lib/python3.10/site-packages/anyio/_core/__pycache__:
# __init__.cpython-310.pyc         _streams.cpython-310.pyc
# _eventloop.cpython-310.pyc       _subprocesses.cpython-310.pyc
# _exceptions.cpython-310.pyc      _synchronization.cpython-310.pyc
# _fileio.cpython-310.pyc          _tasks.cpython-310.pyc
# _resources.cpython-310.pyc       _testing.cpython-310.pyc
# _signals.cpython-310.pyc         _typedattr.cpython-310.pyc
# _sockets.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio/abc:
# __init__.py      _resources.py    _subprocesses.py
# __pycache__      _sockets.py      _tasks.py
# _eventloop.py    _streams.py      _testing.py
#
# ./env/lib/python3.10/site-packages/anyio/abc/__pycache__:
# __init__.cpython-310.pyc      _streams.cpython-310.pyc
# _eventloop.cpython-310.pyc    _subprocesses.cpython-310.pyc
# _resources.cpython-310.pyc    _tasks.cpython-310.pyc
# _sockets.cpython-310.pyc      _testing.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio/streams:
# __init__.py buffered.py memory.py   text.py
# __pycache__ file.py     stapled.py  tls.py
#
# ./env/lib/python3.10/site-packages/anyio/streams/__pycache__:
# __init__.cpython-310.pyc memory.cpython-310.pyc   tls.cpython-310.pyc
# buffered.cpython-310.pyc stapled.cpython-310.pyc
# file.cpython-310.pyc     text.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/anyio-4.4.0.dist-info:
# INSTALLER        METADATA         WHEEL            top_level.txt
# LICENSE          RECORD           entry_points.txt
#
# ./env/lib/python3.10/site-packages/appnope:
# __init__.py __pycache__ _dummy.py   _nope.py
#
# ./env/lib/python3.10/site-packages/appnope/__pycache__:
# __init__.cpython-310.pyc _dummy.cpython-310.pyc   _nope.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/appnope-0.1.4.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/argon2:
# __init__.py         _legacy.py          _utils.py           profiles.py
# __main__.py         _password_hasher.py exceptions.py       py.typed
# __pycache__         _typing.py          low_level.py
#
# ./env/lib/python3.10/site-packages/argon2/__pycache__:
# __init__.cpython-310.pyc         _utils.cpython-310.pyc
# __main__.cpython-310.pyc         exceptions.cpython-310.pyc
# _legacy.cpython-310.pyc          low_level.cpython-310.pyc
# _password_hasher.cpython-310.pyc profiles.cpython-310.pyc
# _typing.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/argon2_cffi-23.1.0.dist-info:
# INSTALLER METADATA  RECORD    WHEEL     licenses
#
# ./env/lib/python3.10/site-packages/argon2_cffi-23.1.0.dist-info/licenses:
# LICENSE
#
# ./env/lib/python3.10/site-packages/argon2_cffi_bindings-21.2.0.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/arrow:
# __init__.py  _version.py  arrow.py     factory.py   locales.py   py.typed
# __pycache__  api.py       constants.py formatter.py parser.py    util.py
#
# ./env/lib/python3.10/site-packages/arrow/__pycache__:
# __init__.cpython-310.pyc  constants.cpython-310.pyc parser.cpython-310.pyc
# _version.cpython-310.pyc  factory.cpython-310.pyc   util.cpython-310.pyc
# api.cpython-310.pyc       formatter.cpython-310.pyc
# arrow.cpython-310.pyc     locales.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/arrow-1.3.0.dist-info:
# INSTALLER LICENSE   METADATA  RECORD    WHEEL
#
# ./env/lib/python3.10/site-packages/asttokens:
# __init__.py       asttokens.py      py.typed
# __pycache__       line_numbers.py   util.py
# astroid_compat.py mark_tokens.py    version.py
#
# ./env/lib/python3.10/site-packages/asttokens/__pycache__:
# __init__.cpython-310.pyc       mark_tokens.cpython-310.pyc
# astroid_compat.cpython-310.pyc util.cpython-310.pyc
# asttokens.cpython-310.pyc      version.cpython-310.pyc
# line_numbers.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/asttokens-2.4.1.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/async_lru:
# __init__.py __pycache__ py.typed
#
# ./env/lib/python3.10/site-packages/async_lru/__pycache__:
# __init__.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/async_lru-2.0.4.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/attr:
# __init__.py        _config.py         _version_info.pyi  filters.pyi
# __init__.pyi       _funcs.py          converters.py      py.typed
# __pycache__        _make.py           converters.pyi     setters.py
# _cmp.py            _next_gen.py       exceptions.py      setters.pyi
# _cmp.pyi           _typing_compat.pyi exceptions.pyi     validators.py
# _compat.py         _version_info.py   filters.py         validators.pyi
#
# ./env/lib/python3.10/site-packages/attr/__pycache__:
# __init__.cpython-310.pyc      _version_info.cpython-310.pyc
# _cmp.cpython-310.pyc          converters.cpython-310.pyc
# _compat.cpython-310.pyc       exceptions.cpython-310.pyc
# _config.cpython-310.pyc       filters.cpython-310.pyc
# _funcs.cpython-310.pyc        setters.cpython-310.pyc
# _make.cpython-310.pyc         validators.cpython-310.pyc
# _next_gen.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/attrs:
# __init__.py   __pycache__   exceptions.py py.typed      validators.py
# __init__.pyi  converters.py filters.py    setters.py
#
# ./env/lib/python3.10/site-packages/attrs/__pycache__:
# __init__.cpython-310.pyc   filters.cpython-310.pyc
# converters.cpython-310.pyc setters.cpython-310.pyc
# exceptions.cpython-310.pyc validators.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/attrs-23.2.0.dist-info:
# INSTALLER METADATA  RECORD    WHEEL     licenses
#
# ./env/lib/python3.10/site-packages/attrs-23.2.0.dist-info/licenses:
# LICENSE
#
# ./env/lib/python3.10/site-packages/aws_requests_auth:
# __init__.py   __pycache__   aws_auth.py   boto_utils.py
#
# ./env/lib/python3.10/site-packages/aws_requests_auth/__pycache__:
# __init__.cpython-310.pyc   boto_utils.cpython-310.pyc
# aws_auth.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/aws_requests_auth-0.4.3.dist-info:
# INSTALLER     METADATA      WHEEL
# LICENSE       RECORD        top_level.txt
#
# ./env/lib/python3.10/site-packages/babel:
# __init__.py   global.dat    localedata.py plural.py     util.py
# __pycache__   languages.py  localtime     py.typed
# core.py       lists.py      messages      support.py
# dates.py      locale-data   numbers.py    units.py
#
# ./env/lib/python3.10/site-packages/babel/__pycache__:
# __init__.cpython-310.pyc   numbers.cpython-310.pyc
# core.cpython-310.pyc       plural.cpython-310.pyc
# dates.cpython-310.pyc      support.cpython-310.pyc
# languages.cpython-310.pyc  units.cpython-310.pyc
# lists.cpython-310.pyc      util.cpython-310.pyc
# localedata.cpython-310.pyc
#
# ./env/lib/python3.10/site-packages/babel/locale-data:
# LICENSE.unicode    en_MP.dat          jv_ID.dat          rif.dat
# aa.dat             en_MS.dat          ka.dat             rif_MA.dat
# aa_DJ.dat          en_MT.dat          ka_GE.dat          rm.dat
# aa_ER.dat          en_MU.dat          kab.dat            rm_CH.dat
# aa_ET.dat          en_MV.dat          kab_DZ.dat         rn.dat
# ab.dat             en_MW.dat          kaj.dat            rn_BI.dat
# ab_GE.dat          en_MY.dat          kaj_NG.dat         ro.dat
# af.dat             en_NA.dat          kam.dat            ro_MD.dat
# af_NA.dat          en_NF.dat          kam_KE.dat         ro_RO.dat
# af_ZA.dat          en_NG.dat          kcg.dat            rof.dat
# agq.dat            en_NL.dat          kcg_NG.dat         rof_TZ.dat
# agq_CM.dat         en_NR.dat          kde.dat            root.dat
# ak.dat             en_NU.dat          kde_TZ.dat         ru.dat
# ak_GH.dat          en_NZ.dat          kea.dat            ru_BY.dat
# am.dat             en_PG.dat          kea_CV.dat         ru_KG.dat
# am_ET.dat          en_PH.dat          ken.dat            ru_KZ.dat
# an.dat             en_PK.dat          ken_CM.dat         ru_MD.dat
# an_ES.dat          en_PN.dat          kgp.dat            ru_RU.dat
# ann.dat            en_PR.dat          kgp_BR.dat         ru_UA.dat
# ann_NG.dat         en_PW.dat          khq.dat            rw.dat
# apc.dat            en_RW.dat          khq_ML.dat         rw_RW.dat
# apc_SY.dat         en_SB.dat          ki.dat             rwk.dat
# ar.dat             en_SC.dat          ki_KE.dat          rwk_TZ.dat
# ar_001.dat         en_SD.dat          kk.dat             sa.dat
# ar_AE.dat          en_SE.dat          kk_KZ.dat          sa_IN.dat
# ar_BH.dat          en_SG.dat          kkj.dat            sah.dat
# ar_DJ.dat          en_SH.dat          kkj_CM.dat         sah_RU.dat
# ar_DZ.dat          en_SI.dat          kl.dat             saq.dat
# ar_EG.dat          en_SL.dat          kl_GL.dat          saq_KE.dat
# ar_EH.dat          en_SS.dat          kln.dat            sat.dat
# ar_ER.dat          en_SX.dat          kln_KE.dat         sat_Deva.dat
# ar_IL.dat          en_SZ.dat          km.dat             sat_Deva_IN.dat
# ar_IQ.dat          en_Shaw.dat        km_KH.dat          sat_Olck.dat
# ar_JO.dat          en_Shaw_GB.dat     kn.dat             sat_Olck_IN.dat
# ar_KM.dat          en_TC.dat          kn_IN.dat          sbp.dat
# ar_KW.dat          en_TK.dat          ko.dat             sbp_TZ.dat
# ar_LB.dat          en_TO.dat          ko_CN.dat          sc.dat
# ar_LY.dat          en_TT.dat          ko_KP.dat          sc_IT.dat
# ar_MA.dat          en_TV.dat          ko_KR.dat          scn.dat
# ar_MR.dat          en_TZ.dat          kok.dat            scn_IT.dat
# ar_OM.dat          en_UG.dat          kok_IN.dat         sd.dat
# ar_PS.dat          en_UM.dat          kpe.dat            sd_Arab.dat
# ar_QA.dat          en_US.dat          kpe_GN.dat         sd_Arab_PK.dat
# ar_SA.dat          en_US_POSIX.dat    kpe_LR.dat         sd_Deva.dat
# ar_SD.dat          en_VC.dat          ks.dat             sd_Deva_IN.dat
# ar_SO.dat          en_VG.dat          ks_Arab.dat        sdh.dat
# ar_SS.dat          en_VI.dat          ks_Arab_IN.dat     sdh_IQ.dat
# ar_SY.dat          en_VU.dat          ks_Deva.dat        sdh_IR.dat
# ar_TD.dat          en_WS.dat          ks_Deva_IN.dat     se.dat
# ar_TN.dat          en_ZA.dat          ksb.dat            se_FI.dat
# ar_YE.dat          en_ZM.dat          ksb_TZ.dat         se_NO.dat
# arn.dat            en_ZW.dat          ksf.dat            se_SE.dat
# arn_CL.dat         eo.dat             ksf_CM.dat         seh.dat
# as.dat             eo_001.dat         ksh.dat            seh_MZ.dat
# as_IN.dat          es.dat             ksh_DE.dat         ses.dat
# asa.dat            es_419.dat         ku.dat             ses_ML.dat
# asa_TZ.dat         es_AR.dat          ku_TR.dat          sg.dat
# ast.dat            es_BO.dat          kw.dat             sg_CF.dat
# ast_ES.dat         es_BR.dat          kw_GB.dat          shi.dat
# az.dat             es_BZ.dat          kxv.dat            shi_Latn.dat
# az_Arab.dat        es_CL.dat          kxv_Deva.dat       shi_Latn_MA.dat
# az_Arab_IQ.dat     es_CO.dat          kxv_Deva_IN.dat    shi_Tfng.dat
# az_Arab_IR.dat     es_CR.dat          kxv_Latn.dat       shi_Tfng_MA.dat
# az_Arab_TR.dat     es_CU.dat          kxv_Latn_IN.dat    shn.dat
# az_Cyrl.dat        es_DO.dat          kxv_Orya.dat       shn_MM.dat
# az_Cyrl_AZ.dat     es_EA.dat          kxv_Orya_IN.dat    shn_TH.dat
# az_Latn.dat        es_EC.dat          kxv_Telu.dat       si.dat
# az_Latn_AZ.dat     es_ES.dat          kxv_Telu_IN.dat    si_LK.dat
# ba.dat             es_GQ.dat          ky.dat             sid.dat
# ba_RU.dat          es_GT.dat          ky_KG.dat          sid_ET.dat
# bal.dat            es_HN.dat          la.dat             sk.dat
# bal_Arab.dat       es_IC.dat          la_VA.dat          sk_SK.dat
# bal_Arab_PK.dat    es_MX.dat          lag.dat            skr.dat
# bal_Latn.dat       es_NI.dat          lag_TZ.dat         skr_PK.dat
# bal_Latn_PK.dat    es_PA.dat          lb.dat             sl.dat
# bas.dat            es_PE.dat          lb_LU.dat          sl_SI.dat
# bas_CM.dat         es_PH.dat          lg.dat             sma.dat
# be.dat             es_PR.dat          lg_UG.dat          sma_NO.dat
# be_BY.dat          es_PY.dat          lij.dat            sma_SE.dat
# be_TARASK.dat      es_SV.dat          lij_IT.dat         smj.dat
# bem.dat            es_US.dat          lkt.dat            smj_NO.dat
# bem_ZM.dat         es_UY.dat          lkt_US.dat         smj_SE.dat
# bew.dat            es_VE.dat          lmo.dat            smn.dat
# bew_ID.dat         et.dat             lmo_IT.dat         smn_FI.dat
# bez.dat            et_EE.dat          ln.dat             sms.dat
# bez_TZ.dat         eu.dat             ln_AO.dat          sms_FI.dat
# bg.dat             eu_ES.dat          ln_CD.dat          sn.dat
# bg_BG.dat          ewo.dat            ln_CF.dat          sn_ZW.dat
# bgc.dat            ewo_CM.dat         ln_CG.dat          so.dat
# bgc_IN.dat         fa.dat             lo.dat             so_DJ.dat
# bgn.dat            fa_AF.dat          lo_LA.dat          so_ET.dat
# bgn_AE.dat         fa_IR.dat          lrc.dat            so_KE.dat
# bgn_AF.dat         ff.dat             lrc_IQ.dat         so_SO.dat
# bgn_IR.dat         ff_Adlm.dat        lrc_IR.dat         sq.dat
# bgn_OM.dat         ff_Adlm_BF.dat     lt.dat             sq_AL.dat
# bgn_PK.dat         ff_Adlm_CM.dat     lt_LT.dat          sq_MK.dat
# bho.dat            ff_Adlm_GH.dat     lu.dat             sq_XK.dat
# bho_IN.dat         ff_Adlm_GM.dat     lu_CD.dat          sr.dat
# blo.dat            ff_Adlm_GN.dat     luo.dat            sr_Cyrl.dat
# blo_BJ.dat         ff_Adlm_GW.dat     luo_KE.dat         sr_Cyrl_BA.dat
# blt.dat            ff_Adlm_LR.dat     luy.dat            sr_Cyrl_ME.dat
# blt_VN.dat         ff_Adlm_MR.dat     luy_KE.dat         sr_Cyrl_RS.dat
# bm.dat             ff_Adlm_NE.dat     lv.dat             sr_Cyrl_XK.dat
# bm_ML.dat          ff_Adlm_NG.dat     lv_LV.dat          sr_Latn.dat
# bm_Nkoo.dat        ff_Adlm_SL.dat     mai.dat            sr_Latn_BA.dat
# bm_Nkoo_ML.dat     ff_Adlm_SN.dat     mai_IN.dat         sr_Latn_ME.dat
# bn.dat             ff_Latn.dat        mas.dat            sr_Latn_RS.dat
# bn_BD.dat          ff_Latn_BF.dat     mas_KE.dat         sr_Latn_XK.dat
# bn_IN.dat          ff_Latn_CM.dat     mas_TZ.dat         ss.dat
# bo.dat             ff_Latn_GH.dat     mdf.dat            ss_SZ.dat
# bo_CN.dat          ff_Latn_GM.dat     mdf_RU.dat         ss_ZA.dat
# bo_IN.dat          ff_Latn_GN.dat     mer.dat            ssy.dat
# br.dat             ff_Latn_GW.dat     mer_KE.dat         ssy_ER.dat
# br_FR.dat          ff_Latn_LR.dat     mfe.dat            st.dat
# brx.dat            ff_Latn_MR.dat     mfe_MU.dat         st_LS.dat
# brx_IN.dat         ff_Latn_NE.dat     mg.dat             st_ZA.dat
# bs.dat             ff_Latn_NG.dat     mg_MG.dat          su.dat
# bs_Cyrl.dat        ff_Latn_SL.dat     mgh.dat            su_Latn.dat
# bs_Cyrl_BA.dat     ff_Latn_SN.dat     mgh_MZ.dat         su_Latn_ID.dat
# bs_Latn.dat        fi.dat             mgo.dat            sv.dat
# bs_Latn_BA.dat     fi_FI.dat          mgo_CM.dat         sv_AX.dat
# bss.dat            fil.dat            mi.dat             sv_FI.dat
# bss_CM.dat         fil_PH.dat         mi_NZ.dat          sv_SE.dat
# byn.dat            fo.dat             mic.dat            sw.dat
# byn_ER.dat         fo_DK.dat          mic_CA.dat         sw_CD.dat
# ca.dat             fo_FO.dat          mk.dat             sw_KE.dat
# ca_AD.dat          fr.dat             mk_MK.dat          sw_TZ.dat
# ca_ES.dat          fr_BE.dat          ml.dat             sw_UG.dat
# ca_ES_VALENCIA.dat fr_BF.dat          ml_IN.dat          syr.dat
# ca_FR.dat          fr_BI.dat          mn.dat             syr_IQ.dat
# ca_IT.dat          fr_BJ.dat          mn_MN.dat          syr_SY.dat
# cad.dat            fr_BL.dat          mn_Mong.dat        szl.dat
# cad_US.dat         fr_CA.dat          mn_Mong_CN.dat     szl_PL.dat
# cch.dat            fr_CD.dat          mn_Mong_MN.dat     ta.dat
# cch_NG.dat         fr_CF.dat          mni.dat            ta_IN.dat
# ccp.dat            fr_CG.dat          mni_Beng.dat       ta_LK.dat
# ccp_BD.dat         fr_CH.dat          mni_Beng_IN.dat    ta_MY.dat
# ccp_IN.dat         fr_CI.dat          mni_Mtei.dat       ta_SG.dat
# ce.dat             fr_CM.dat          mni_Mtei_IN.dat    te.dat
# ce_RU.dat          fr_DJ.dat          moh.dat            te_IN.dat
# ceb.dat            fr_DZ.dat          moh_CA.dat         teo.dat
# ceb_PH.dat         fr_FR.dat          mr.dat             teo_KE.dat
# cgg.dat            fr_GA.dat          mr_IN.dat          teo_UG.dat
# cgg_UG.dat         fr_GF.dat          ms.dat             tg.dat
# cho.dat            fr_GN.dat          ms_Arab.dat        tg_TJ.dat
# cho_US.dat         fr_GP.dat          ms_Arab_BN.dat     th.dat
# chr.dat            fr_GQ.dat          ms_Arab_MY.dat     th_TH.dat
# chr_US.dat         fr_HT.dat          ms_BN.dat          ti.dat
# cic.dat            fr_KM.dat          ms_ID.dat          ti_ER.dat
# cic_US.dat         fr_LU.dat          ms_MY.dat          ti_ET.dat
# ckb.dat            fr_MA.dat          ms_SG.dat          tig.dat
# ckb_IQ.dat         fr_MC.dat          mt.dat             tig_ER.dat
# ckb_IR.dat         fr_MF.dat          mt_MT.dat          tk.dat
# co.dat             fr_MG.dat          mua.dat            tk_TM.dat
# co_FR.dat          fr_ML.dat          mua_CM.dat         tn.dat
# cs.dat             fr_MQ.dat          mus.dat            tn_BW.dat
# cs_CZ.dat          fr_MR.dat          mus_US.dat         tn_ZA.dat
# csw.dat            fr_MU.dat          my.dat             to.dat
# csw_CA.dat         fr_NC.dat          my_MM.dat          to_TO.dat
# cu.dat             fr_NE.dat          myv.dat            tok.dat
# cu_RU.dat          fr_PF.dat          myv_RU.dat         tok_001.dat
# cv.dat             fr_PM.dat          mzn.dat            tpi.dat
# cv_RU.dat          fr_RE.dat          mzn_IR.dat         tpi_PG.dat
# cy.dat             fr_RW.dat          naq.dat            tr.dat
# cy_GB.dat          fr_SC.dat          naq_NA.dat         tr_CY.dat
# da.dat             fr_SN.dat          nb.dat             tr_TR.dat
# da_DK.dat          fr_SY.dat          nb_NO.dat          trv.dat
# da_GL.dat          fr_TD.dat          nb_SJ.dat          trv_TW.dat
# dav.dat            fr_TG.dat          nd.dat             trw.dat
# dav_KE.dat         fr_TN.dat          nd_ZW.dat          trw_PK.dat
# de.dat             fr_VU.dat          nds.dat            ts.dat
# de_AT.dat          fr_WF.dat          nds_DE.dat         ts_ZA.dat
# de_BE.dat          fr_YT.dat          nds_NL.dat         tt.dat
# de_CH.dat          frr.dat            ne.dat             tt_RU.dat
# de_DE.dat          frr_DE.dat         ne_IN.dat          twq.dat
# de_IT.dat          fur.dat            ne_NP.dat          twq_NE.dat
# de_LI.dat          fur_IT.dat         nl.dat             tyv.dat
# de_LU.dat          fy.dat             nl_AW.dat          tyv_RU.dat
# dje.dat            fy_NL.dat          nl_BE.dat          tzm.dat
# dje_NE.dat         ga.dat             nl_BQ.dat          tzm_MA.dat
# doi.dat            ga_GB.dat          nl_CW.dat          ug.dat
# doi_IN.dat         ga_IE.dat          nl_NL.dat          ug_CN.dat
# dsb.dat            gaa.dat            nl_SR.dat          uk.dat
# dsb_DE.dat         gaa_GH.dat         nl_SX.dat          uk_UA.dat
# dua.dat            gd.dat             nmg.dat            ur.dat
# dua_CM.dat         gd_GB.dat          nmg_CM.dat         ur_IN.dat
# dv.dat             gez.dat            nn.dat             ur_PK.dat
# dv_MV.dat          gez_ER.dat         nn_NO.dat          uz.dat
# dyo.dat            gez_ET.dat         nnh.dat            uz_Arab.dat
# dyo_SN.dat         gl.dat             nnh_CM.dat         uz_Arab_AF.dat
# dz.dat             gl_ES.dat          no.dat             uz_Cyrl.dat
# dz_BT.dat          gn.dat             nqo.dat            uz_Cyrl_UZ.dat
# ebu.dat            gn_PY.dat          nqo_GN.dat         uz_Latn.dat
# ebu_KE.dat         gsw.dat            nr.dat             uz_Latn_UZ.dat
# ee.dat             gsw_CH.dat         nr_ZA.dat          vai.dat
# ee_GH.dat          gsw_FR.dat         nso.dat            vai_Latn.dat
# ee_TG.dat          gsw_LI.dat         nso_ZA.dat         vai_Latn_LR.dat
# el.dat             gu.dat             nus.dat            vai_Vaii.dat
# el_CY.dat          gu_IN.dat          nus_SS.dat         vai_Vaii_LR.dat
# el_GR.dat          guz.dat            nv.dat             ve.dat
# el_POLYTON.dat     guz_KE.dat         nv_US.dat          ve_ZA.dat
# en.dat             gv.dat             ny.dat             vec.dat
# en_001.dat         gv_IM.dat          ny_MW.dat          vec_IT.dat
# en_150.dat         ha.dat             nyn.dat            vi.dat
# en_AE.dat          ha_Arab.dat        nyn_UG.dat         vi_VN.dat
# en_AG.dat          ha_Arab_NG.dat     oc.dat             vmw.dat
# en_AI.dat          ha_Arab_SD.dat     oc_ES.dat          vmw_MZ.dat
# en_AS.dat          ha_GH.dat          oc_FR.dat          vo.dat
# en_AT.dat          ha_NE.dat          om.dat             vo_001.dat
# en_AU.dat          ha_NG.dat          om_ET.dat          vun.dat
# en_BB.dat          haw.dat            om_KE.dat          vun_TZ.dat
# en_BE.dat          haw_US.dat         or.dat             wa.dat
# en_BI.dat          he.dat             or_IN.dat          wa_BE.dat
# en_BM.dat          he_IL.dat          os.dat             wae.dat
# en_BS.dat          hi.dat             os_GE.dat          wae_CH.dat
# en_BW.dat          hi_IN.dat          os_RU.dat          wal.dat
# en_BZ.dat          hi_Latn.dat        osa.dat            wal_ET.dat
# en_CA.dat          hi_Latn_IN.dat     osa_US.dat         wbp.dat
# en_CC.dat          hnj.dat            pa.dat             wbp_AU.dat
# en_CH.dat          hnj_Hmnp.dat       pa_Arab.dat        wo.dat
# en_CK.dat          hnj_Hmnp_US.dat    pa_Arab_PK.dat     wo_SN.dat
# en_CM.dat          hr.dat             pa_Guru.dat        xh.dat
# en_CX.dat          hr_BA.dat          pa_Guru_IN.dat     xh_ZA.dat
# en_CY.dat          hr_HR.dat          pap.dat            xnr.dat
# en_DE.dat          hsb.dat            pap_AW.dat         xnr_IN.dat
# en_DG.dat          hsb_DE.dat         pap_CW.dat         xog.dat
# en_DK.dat          hu.dat             pcm.dat            xog_UG.dat
# en_DM.dat          hu_HU.dat          pcm_NG.dat         yav.dat
# en_Dsrt.dat        hy.dat             pis.dat            yav_CM.dat
# en_Dsrt_US.dat     hy_AM.dat          pis_SB.dat         yi.dat
# en_ER.dat          ia.dat             pl.dat             yi_UA.dat
# en_FI.dat          ia_001.dat         pl_PL.dat          yo.dat
# ...
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/docmanager-extension:
# download.json     package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/documentsearch-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/extensionmanager-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/filebrowser-extension:
# browser.json          open-browser-tab.json package.json.orig
# download.json         open-with.json        widget.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/fileeditor-extension:
# completer.json    package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/help-extension:
# about.json          jupyter-forum.json  launch-classic.json package.json.orig
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/htmlviewer-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/hub-extension:
# menu.json         package.json.orig
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/imageviewer-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/inspector-extension:
# consoles.json     inspector.json    notebooks.json    package.json.orig
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/launcher-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/logconsole-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/lsp-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/mainmenu-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/markdownviewer-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/mathjax-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/metadataform-extension:
# metadataforms.json package.json.orig
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/notebook-extension:
# completer.json    package.json.orig tools.json
# export.json       panel.json        tracker.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/running-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/settingeditor-extension:
# form-ui.json      package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/shortcuts-extension:
# package.json.orig shortcuts.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/statusbar-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/terminal-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/toc-extension:
# package.json.orig registry.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/tooltip-extension:
# consoles.json     files.json        notebooks.json    package.json.orig
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/translation-extension:
# package.json.orig plugin.json
#
# ./env/share/jupyter/lab/schemas/@jupyterlab/workspaces-extension:
# menu.json         package.json.orig sidebar.json
#
# ./env/share/jupyter/lab/static:
# 1036.b7aaba381aaa04073a6b.js
# 1036.b7aaba381aaa04073a6b.js.LICENSE.txt
# 1085.0b67f0736d85ec41fdd4.js
# 1142.d5442a459b18907c1f91.js
# 1166.08f9e1fd722f61c9b69c.js
# 1168.0a95b9c93afe61ceb527.js
# 1294.9d27be1098bc8abebe3f.js
# 1410.d8f5e39e1e01d696d2ab.js
# 1420.e8486ed074346bc629ca.js
# 1448.c391061d8a8344f9d177.js
# 1452.4cc17f31511d1f9c6052.js
# 1467.dcd89539f6477c1367af.js
# 1550.09375e869bc25429b07a.js
# 1581.e988a625b879002dcc04.js
# 1581.e988a625b879002dcc04.js.LICENSE.txt
# 1608.61240f3db67d3d952790.js
# 1610.5f9622f4a515447f78fe.js
# 1610.5f9622f4a515447f78fe.js.LICENSE.txt
# 1716.a6bbe1ae8a1986a73623.js
# 1760.9a71f4501e9bbaa4c4d8.js
# 1776.4f9305d35480467b23c9.js
# 1861.4fc7b4afe2b09eb6b5c0.js
# 1903.3b452e8ec30e57dbaba5.js
# 1917.05d73322caab1f77e3bf.js
# 1929.96e62233aa6f2a8363d4.js
# 1945.0fbbfe93a4aedd91875c.js
# 1954.07d96e4020ed6e543d25.js
# 1993.f8c5682f95ffa75cbaf6.js
# 1cb1c39ea642f26a4dfe.woff
# 2039.aa079dac5c520f93b234.js
# 2090.abc86741318f76c3d726.js
# 2091.0ad2070604beb93b34c5.js
# 2102.ff1893c4bd1104a1f57d.js
# 2104.96885e414ee656615c2b.js
# 2145.be9ec610f29703694fcf.js
# 2254.55c69210925ec9b28dd9.js
# 226.5dc3528c008170b37b21.js
# 2295.cda0f7182bf2a1a03c5a.js
# 2363.6eef078cb37c32d7fbc3.js
# 2459.9f9cb02561de1bec73ff.js
# 2485.dab750ed66209df61fe1.js
# 2551.b07d561a12360c38c589.js
# 2579.b19edefeb9ee4daed4bd.js
# 2584.e4b860ab848de94978cf.js
# 2646.0864fb63d7ab1ed16893.js
# 2655.71a94960aa4ab2040d8f.js
# 26683bf201fb258a2237.woff
# 2727.6925b8cf1c5363f40138.js
# 2755.696bab6bdca0d9a78131.js
# 2800.8acae2f2fef55d2ccdf2.js
# 2857.27a6e85f5c4c092ab8a2.js
# 2909.e190307f7f84c7691068.js
# 2929.b88233153dbf33f40b29.js
# 2953.92ff8f12bad6ee06859c.js
# 2990.ea15322a41d3f133989b.js
# 2995.334184c36a45c82ad564.js
# 3056.8a73f6aacd8ca45f84f9.js
# 30e889b58cbc51adfbb0.woff
# 3123.85cea4be2e2ed3f9654f.js
# 32792104b5ef69eded90.woff
# 3306.8bdc49ad1a7ca593a838.js
# 3308.764d71af7e591cdb1345.js
# 3520.3495b98946de6960ace8.js
# 3528.3b5ef5f31d460b5fcd01.js
# 3547.2a00f51cd14b6060c5d6.js
# 3549.24f2fe646d8128bc9db0.js
# 355254db9ca10a09a3b5.woff
# 3601.5c17c015d71b69ddcab3.js
# 36e0d72d8a7afc696a3e.woff
# 3711.150292a21fd47be1c05f.js
# 3724.a4657dc16be2ffc49282.js
# 373c04fd2418f5c77eea.eot
# 378.6d0f0fc4c8a2eb80ac43.js
# 3783.36bf783a511cc87997c0.js
# 3807.08a8fd824036c30b3746.js
# 383.db345dbeef5ef774e50c.js
# 3871.ba96e5b53bb16df56618.js
# 3923.f29c06abdcb560130471.js
# 3935.905285b8e22c337968ed.js
# 3935.905285b8e22c337968ed.js.LICENSE.txt
# 3962.50786e3ed9a01329a4a0.js
# 3bc6ecaae7ecf6f8d7f8.woff
# 3de784d07b9fa8f104c1.woff
# 3f6d3488cf65374f6f67.woff
# 4008.86acbefff6de679f77b5.js
# 4008.86acbefff6de679f77b5.js.LICENSE.txt
# 4017.096a74a538e031b6d346.js
# 4043.c57e85faf640ba37b87c.js
# 406.81906f96059e31e907a2.js
# 4086.3087c0abed5ca45b823b.js
# 4136.af02ad1642e802531b76.js
# 4136.af02ad1642e802531b76.js.LICENSE.txt
# 4139.303ee7374c742287be85.js
# 4155.5a8d6736017097028d78.js
# 4244.3d69bbe0937f69ca1f80.js
# 4283.f6092d8b7f2e53118d1b.js
# 4291.e5d8997127541f75fdaf.js
# 4405.196dd63db3761b4bb7fe.js
# 4419.93938494f456cd76a7e3.js
# 4452.2f8819684b96ecff5231.js
# 4457.0add5dec58939a80e2c3.js
# 4503.5f41fcfefb7e83b6190e.js
# 4519.6b784d052db42e93eff2.js
# 4562.72444a09f5f092646490.js
# 4591.428531724f49fe824ffa.js
# 46.fb119c5e5b1e0c72a00f.js
# 4743.d4e9658ea25301e15a94.js
# 4765.093b4f8b3cee1251db8d.js
# 481e39042508ae313a60.woff
# 4878.73004381601237a3ef9c.js
# 49.43ad810fe0adbd6be564.js
# 4912.4371d46fb589b52e231b.js
# 4912.4371d46fb589b52e231b.js.LICENSE.txt
# 4986.c819184e09e1e15ef06b.js
# 5041.cdc120bda0a0dec4cfc2.js
# 5083.4926253681abafa806f9.js
# 5157.9c77dc27a251d4135876.js
# 5201.26a6f909d5e2eaa4ada3.js
# 5203.c002d40ac647dc6e1d61.js
# 526.601d8ddd8347cd7790b9.js
# 5331.0cd3f010bb08983ec3fd.js
# 5440.2541fcda12b661665148.js
# 5521.ce4a0274596e0325374c.js
# 5746.e4434ef2027bcc5ed0c9.js
# 5794.3cb2bcd1a3e23d0c084e.js
# 581.2b878ed37172aced15b5.js
# 5881.3946238aa4afdcf4f964.js
# 5959.a6b1fd3b03d3649ea8b1.js
# 5cda41563a095bd70c78.woff
# 6001.963601fcecb8b4c1d1f1.js
# 6059.d83e7323b2ee1aa16009.js
# 6163.f5b51a9f0df4846ba40f.js
# 6177.a4ddefac453fccec8424.js
# 6207.a8079c8d8a61039dd530.js
# 6243.2efd673d1304c43b7b78.js
# 6267.1def2916929e185ab9fc.js
# 6359.4b994bfd6b1dea2d6fe3.js
# 6436.8d9ba427de4ab1053871.js
# 6443.e6b52d3732b3e8513a71.js
# 6515.56c63929fb079a820cbc.js
# 6532.598324868e83c4cbe4e4.js
# 6560.f42276a0b1b92aea515b.js
# 6595.6a1d7e1abbf186dd119b.js
# 6686.3c518aa6e5f9785fb486.js
# 6770.e0d2c4918e1b8e92cee0.js
# 6778.345e6ac9818e30317310.js
# 6815.0b699f0c162a24b0dbe3.js
# 6888.f71353e198bce9c2f409.js
# 6898.742a7062fa979fb68a80.js
# 7080.1330328bb6f46b4da81e.js
# 7112.d5120c85ebd17620dda0.js
# 7161.353c3ab960df72e6f1ea.js
# 7173.e28f63dbd553818e07d3.js
# 7178.00544e04232624c49cca.js
# 7178.00544e04232624c49cca.js.LICENSE.txt
# 721921bab0d001ebff02.woff
# 7245.c0cae8787dcd00b991b7.js
# 7272.72081c10e0f645b0631a.js
# 7294.badf85a3180703d63f62.js
# 7294.badf85a3180703d63f62.js.LICENSE.txt
# 72bc573386dd1d48c5bb.woff
# 7313.73992ed2c886c6f8f00b.js
# 7313.73992ed2c886c6f8f00b.js.LICENSE.txt
# 7317.af8a7da0f881a22752c1.js
# 7318.f5a0db6dd94488328be5.js
# 7363.abe8e31a91e113753bae.js
# 7384.60351e008d8f687e8fcc.js
# 7390.8253478b90f756692702.js
# 7426.c83966ccc62601d391bd.js
# 7426.c83966ccc62601d391bd.js.LICENSE.txt
# 745.85516a9bb83bcd94d00d.js
# 7451.c0257dbfdd320e2c21f5.js
# 7451.c0257dbfdd320e2c21f5.js.LICENSE.txt
# 7472.58ba8647a489d019c2ef.js
# 7473.5012397d10d3b945ecaa.js
# 7508.b902347f820c70cd386a.js
# 7571.f66d83573a9eb5862d6f.js
# 7629.1f295461ebf56a48c197.js
# 7669.343e259c4c8269479f5b.js
# 7702.c479c69f7a532f7b3fd5.js
# 7730.7e3a9fb140d2d55a51fc.js
# 7731.26db150e967313b7a7e2.js
# 7734.b08c15e9f538f44d0f52.js
# 7763.19a095394000f9ef62bd.js
# 7763.19a095394000f9ef62bd.js.LICENSE.txt
# 7775.3e0dee729369fe3d5008.js
# 7823.f3c8154418bc214dc89a.js
# 7827.e36d073d947bf02a05e3.js
# 7848.e83aa4b90ae87209abb8.js
# 786.8a99ee7dbd7bd0eb9dce.js
# 7877.a4c46a784149533b91d4.js
# 7887.128a155df5d25e88c0ce.js
# 7946.7fe46d47492e459b7cb5.js
# 795.c780bf11bb08527e3c84.js
# 79d088064beb3826054f.eot
# 8002.25f64485372af5158c83.js
# 8010.1cf8237e9def8404f355.js
# 8012.40cb006f0c180ebafa91.js
# 812.5f1e3bf55e749a312b07.js
# 8152.5baac73844a065f34284.js
# 8267.01bec3949b651535e6f5.js
# 8285.1eac7b7582569be1c3a8.js
# 8302.5c5e5a2da7fe74b12a1d.js
# 8319.80fcbc832e1eb20b71e7.js
# 8322.288af285dac9cb9a8800.js
# 8347.573b699e3590729bfa8a.js
# 8405.154ba4b17a2dec22a355.js
# 8462.74d5f5afd4f9d7825eed.js
# 8493.fc635229db38e6fc6aa2.js
# 8498.27a245b23921914bf5c2.js
# 8512.1af96655287fd124877b.js
# 8678.dcd3dab9025b13eb9be8.js
# 870673df72e70f87c91a.woff
# 8710.5fc5ecb762fb4494db02.js
# 8738.782816e9072ac38762b4.js
# 8771.ac4c870ed77005ec8e34.js
# 8787.4d36d28dcf94bf59cbfe.js
# 8805.0f14a91b024b59c039a7.js
# 881.972f79365eed0f77378e.js
# 8823.2ff947bcd96cc0723058.js
# 8875.88988caaba1e33edad5b.js
# 88b98cad3688915e50da.woff
# 8ea8791754915a898a31.woff2
# 8ea8dbb1b02e6f730f55.woff
# 9.82c3bf54739d037b7bd1.js
# 9030.61b135ed4411056792ab.js
# 9041.d439f3e9bdd4ea5a681b.js
# 9055.bd710a8db8883a836b59.js
# 9109.fa3ee74a5c0f378f4d51.js
# 9192.db4337a516b7f38d1f89.js
# 9222.1c2a8e69a2de57dd1984.js
# 9230.58b8c42b730e1a56e69b.js
# 9265.bc2b66a4502cdfcfc14f.js
# 9362.823dcfac216f8057452d.js
# 9395.b59dceae72715c9f885c.js
# 9409.34c33ed11e2d6f318480.js
# 942.68bd92fc10c9f9d7004f.js
# 9440.04751e25c9cde059ff37.js
# 9445.fe5e9e5b728de8d15873.js
# 9545.f8eefaa775e9413140d0.js
# 9621.9cbfa52c42927bb398b4.js
# 9653.52cac2cc6fb3dc3bf28a.js
# 9674eb1bd55047179038.svg
# 9738.c0234a1f7f6ac262f560.js
# 9747.6dd327f4928c6989ea8a.js
# 9747.6dd327f4928c6989ea8a.js.LICENSE.txt
# 9826.406d2a71dc45995bc549.js
# 9826.406d2a71dc45995bc549.js.LICENSE.txt
# 9834b82ad26e2a37583d.woff2
# 9984.6ba5355e0d5487d5ac63.js
# a009bea404f7a500ded4.woff
# a3b9817780214caf01e8.svg
# af04542b29eaac04550a.woff
# af6397503fcefbd61397.ttf
# af96f67d7accf5fd2a4a.woff
# b418136e3b384baaadec.woff
# be0a084962d8066884f7.svg
# bootstrap.js
# build_log.json
# c49810b53ecc0d87d802.woff
# c56da8d69f1a0208b8e0.woff
# cb9e9e693192413cde2b.woff
# cda59d6efffa685830fd.ttf
# e4299464e7b012968eed.eot
# e42a88444448ac3d6054.woff2
# e8711bbb871afd8e9dea.ttf
# f9217f66874b0c01cd8c.woff
# fc6ddf5df402b263cfb1.woff
# index.html
# index.out.js
# jlab_core.c1feae0690cd2229a88c.js
# main.7e428eab963a260fd94b.js
# package.json
# style.js
# third-party-licenses.json
#
# ./env/share/jupyter/lab/themes:
# @jupyterlab
#
# ./env/share/jupyter/lab/themes/@jupyterlab:
# theme-dark-extension               theme-light-extension
# theme-dark-high-contrast-extension
#
# ./env/share/jupyter/lab/themes/@jupyterlab/theme-dark-extension:
# index.css index.js
#
# ./env/share/jupyter/lab/themes/@jupyterlab/theme-dark-high-contrast-extension:
# index.css index.js
#
# ./env/share/jupyter/lab/themes/@jupyterlab/theme-light-extension:
# index.css index.js
#
# ./env/share/jupyter/labextensions:
# @jupyter-notebook   @jupyter-widgets    jupyterlab_pygments
#
# ./env/share/jupyter/labextensions/@jupyter-notebook:
# lab-extension
#
# ./env/share/jupyter/labextensions/@jupyter-notebook/lab-extension:
# package.json schemas      static
#
# ./env/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas:
# @jupyter-notebook
#
# ./env/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas/@jupyter-notebook:
# lab-extension
#
# ./env/share/jupyter/labextensions/@jupyter-notebook/lab-extension/schemas/@jupyter-notebook/lab-extension:
# interface-switcher.json launch-tree.json        package.json.orig
#
# ./env/share/jupyter/labextensions/@jupyter-notebook/lab-extension/static:
# 568.9cd06af416befd593828.js         remoteEntry.d04be841d48ffe2a9bdd.js
# 678.af323c3ff765541c6aa4.js         style.js
# 928.6d26fccf0ddab13bf5bb.js         third-party-licenses.json
# 93.eae3497dd223d842d198.js
#
# ./env/share/jupyter/labextensions/@jupyter-widgets:
# jupyterlab-manager
#
# ./env/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager:
# install.json package.json schemas      static
#
# ./env/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas:
# @jupyter-widgets
#
# ./env/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets:
# jupyterlab-manager
#
# ./env/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/schemas/@jupyter-widgets/jupyterlab-manager:
# package.json.orig plugin.json
#
# ./env/share/jupyter/labextensions/@jupyter-widgets/jupyterlab-manager/static:
# 327.68dbf8491690b3aff1e7.js             651.fe40a967a60b543cf15c.js.LICENSE.txt
# 39.1949673a9fd9c144c15b.js              701.043aefe0b66133629348.js
# 420.68e690774ec05e4e9665.js             722.3fefeac9cae358348cbc.js
# 439.33696bc45fbd403becbb.js             727.2abc0b27bd0932fb5f81.js
# 439.33696bc45fbd403becbb.js.LICENSE.txt 898.402374e73a78886eba74.js
# 446.fdf8b1b233cb8c1783f6.js             remoteEntry.5586bbdee77c5d90dd3c.js
# 586.f9a8b8b4dd029695640b.js             style.js
# 647.e39f528c8fee8adb9110.js             third-party-licenses.json
# 651.fe40a967a60b543cf15c.js
#
# ./env/share/jupyter/labextensions/jupyterlab_pygments:
# install.json package.json static
#
# ./env/share/jupyter/labextensions/jupyterlab_pygments/static:
# 568.1e2faa2ba0bbe59c4780.js         style.js
# 747.67662283a5707eeb4d4c.js         third-party-licenses.json
# remoteEntry.5cbb9d2323598fbda535.js
#
# ./env/share/jupyter/nbconvert:
# templates
#
# ./env/share/jupyter/nbconvert/templates:
# asciidoc      classic       latex         reveal        webpdf
# base          compatibility markdown      rst
# basic         lab           python        script
#
# ./env/share/jupyter/nbconvert/templates/asciidoc:
# conf.json         index.asciidoc.j2
#
# ./env/share/jupyter/nbconvert/templates/base:
# cell_id_anchor.j2       display_priority.j2     mathjax.html.j2
# celltags.j2             jupyter_widgets.html.j2 null.j2
#
# ./env/share/jupyter/nbconvert/templates/basic:
# conf.json     index.html.j2
#
# ./env/share/jupyter/nbconvert/templates/classic:
# base.html.j2  conf.json     index.html.j2 static
#
# ./env/share/jupyter/nbconvert/templates/classic/static:
# style.css
#
# ./env/share/jupyter/nbconvert/templates/compatibility:
# display_priority.tpl full.tpl
#
# ./env/share/jupyter/nbconvert/templates/lab:
# base.html.j2      index.html.j2     static
# conf.json         mermaidjs.html.j2
#
# ./env/share/jupyter/nbconvert/templates/lab/static:
# index.css       theme-dark.css  theme-light.css
#
# ./env/share/jupyter/nbconvert/templates/latex:
# base.tex.j2              index.tex.j2             style_bw_python.tex.j2
# conf.json                null.j2                  style_ipython.tex.j2
# display_priority.j2      report.tex.j2            style_jupyter.tex.j2
# document_contents.tex.j2 style_bw_ipython.tex.j2  style_python.tex.j2
#
# ./env/share/jupyter/nbconvert/templates/markdown:
# conf.json   index.md.j2
#
# ./env/share/jupyter/nbconvert/templates/python:
# conf.json   index.py.j2
#
# ./env/share/jupyter/nbconvert/templates/reveal:
# base.html.j2     conf.json        static
# cellslidedata.j2 index.html.j2
#
# ./env/share/jupyter/nbconvert/templates/reveal/static:
# custom_reveal.css
#
# ./env/share/jupyter/nbconvert/templates/rst:
# conf.json    index.rst.j2
#
# ./env/share/jupyter/nbconvert/templates/script:
# conf.json script.j2
#
# ./env/share/jupyter/nbconvert/templates/webpdf:
# conf.json    index.pdf.j2
#
# ./env/share/jupyter/nbextensions:
# jupyter-js-widgets
#
# ./env/share/jupyter/nbextensions/jupyter-js-widgets:
# extension.js             extension.js.LICENSE.txt extension.js.map
#
# ./env/share/man:
# man1
#
# ./env/share/man/man1:
# ipython.1

# %%
import pandas as pd
import quilt3 as q3

pd.read_parquet("data/Atlantic-HURDAT2.parquet")
# Out:
#    YYYY-MM-DD TimeUTC Record identifier Status of system Latitude Longitude  \
# 0    18510625    0000                                 HU    28.0N     94.8W
# 1    18510625    0600                                 HU    28.0N     95.4W
# 2    18510625    1200                                 HU    28.0N     96.0W
# 3    18510625    1800                                 HU    28.1N     96.5W
# 4    18510625    2100                 L               HU    28.2N     96.8W
# ..        ...     ...               ...              ...      ...       ...
# 21   20201117    1200                                 HU    13.7N     84.7W
# 22   20201117    1800                                 TS    13.7N     85.7W
# 23   20201118    0000                                 TS    13.8N     86.7W
# 24   20201118    0600                                 TS    13.8N     87.8W
# 25   20201118    1200                                 TD    13.7N     89.0W
#
#    Max. sustained wind (knots) Min. pressure (millibars)  \
# 0                           80                      -999
# 1                           80                      -999
# 2                           80                      -999
# 3                           80                      -999
# 4                           80                      -999
# ..                         ...                       ...
# 21                          75                       965
# 22                          55                       988
# 23                          40                      1000
# 24                          35                      1005
# 25                          25                      1006
#
#    34 kt wind max. NE (nautical miles) 34 kt wind max. SE (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                 170                                 110
# 22                                 150                                  70
# 23                                 140                                   0
# 24                                 140                                   0
# 25                                   0                                   0
#
#     ... 50 kt wind max. NW (nautical miles)  \
# 0   ...                                -999
# 1   ...                                -999
# 2   ...                                -999
# 3   ...                                -999
# 4   ...                                -999
# ..  ...                                 ...
# 21  ...                                  50
# 22  ...                                   0
# 23  ...                                   0
# 24  ...                                   0
# 25  ...                                   0
#
#    64 kt wind max. NE (nautical miles) 64 kt wind max. SE (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                  30                                   0
# 22                                   0                                   0
# 23                                   0                                   0
# 24                                   0                                   0
# 25                                   0                                   0
#
#    64 kt wind max. SW (nautical miles) 64 kt wind max. NW (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                   0                                  20
# 22                                   0                                   0
# 23                                   0                                   0
# 24                                   0                                   0
# 25                                   0                                   0
#
#    Basin ATCF Cyclone Number HYear     Name Num. best track entries
# 0     AL                  01  1851  UNNAMED                      14
# 1     AL                  01  1851  UNNAMED                      14
# 2     AL                  01  1851  UNNAMED                      14
# 3     AL                  01  1851  UNNAMED                      14
# 4     AL                  01  1851  UNNAMED                      14
# ..   ...                 ...   ...      ...                     ...
# 21    AL                  31  2020     IOTA                      26
# 22    AL                  31  2020     IOTA                      26
# 23    AL                  31  2020     IOTA                      26
# 24    AL                  31  2020     IOTA                      26
# 25    AL                  31  2020     IOTA                      26
#
# [52717 rows x 25 columns]

# %% [markdown]
# ## Browse a data package
# Sometimes we want to install part of a data package. We can do that with `quilt3 install data/package/subfoler`. Other times, we might want to just see what's in a package:

# %%
p = q3.Package.browse("examples/hurdat2", "s3://quilt-example")
p
# Out:
# Loading manifest: 100%|██████████| 7/7 [00:00<00:00, 6.82k/s]
# (remote Package)
#  └─.quiltignore
#  └─Atlantic-HURDAT2.parquet
#  └─README.md
#  └─external/
#    └─hurdat2-1851-2020-052921.txt
#    └─hurdat2-format-nov2019.pdf
#  └─quilt_summarize.json

# %% [markdown]
# Here you'll notice that we only downloaded the package *manifest* not the full dataset. The manifest gives us metdat as to what's inside the package, but contains only pointers to the *primary data*.
#
# ### Pulling data from S3 into memory
# Suppose we wanted not to download anything, but just pull a Parquet file into memory:

# %%
p["Atlantic-HURDAT2.parquet"]()
# Out:
#    YYYY-MM-DD TimeUTC Record identifier Status of system Latitude Longitude  \
# 0    18510625    0000                                 HU    28.0N     94.8W
# 1    18510625    0600                                 HU    28.0N     95.4W
# 2    18510625    1200                                 HU    28.0N     96.0W
# 3    18510625    1800                                 HU    28.1N     96.5W
# 4    18510625    2100                 L               HU    28.2N     96.8W
# ..        ...     ...               ...              ...      ...       ...
# 21   20201117    1200                                 HU    13.7N     84.7W
# 22   20201117    1800                                 TS    13.7N     85.7W
# 23   20201118    0000                                 TS    13.8N     86.7W
# 24   20201118    0600                                 TS    13.8N     87.8W
# 25   20201118    1200                                 TD    13.7N     89.0W
#
#    Max. sustained wind (knots) Min. pressure (millibars)  \
# 0                           80                      -999
# 1                           80                      -999
# 2                           80                      -999
# 3                           80                      -999
# 4                           80                      -999
# ..                         ...                       ...
# 21                          75                       965
# 22                          55                       988
# 23                          40                      1000
# 24                          35                      1005
# 25                          25                      1006
#
#    34 kt wind max. NE (nautical miles) 34 kt wind max. SE (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                 170                                 110
# 22                                 150                                  70
# 23                                 140                                   0
# 24                                 140                                   0
# 25                                   0                                   0
#
#     ... 50 kt wind max. NW (nautical miles)  \
# 0   ...                                -999
# 1   ...                                -999
# 2   ...                                -999
# 3   ...                                -999
# 4   ...                                -999
# ..  ...                                 ...
# 21  ...                                  50
# 22  ...                                   0
# 23  ...                                   0
# 24  ...                                   0
# 25  ...                                   0
#
#    64 kt wind max. NE (nautical miles) 64 kt wind max. SE (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                  30                                   0
# 22                                   0                                   0
# 23                                   0                                   0
# 24                                   0                                   0
# 25                                   0                                   0
#
#    64 kt wind max. SW (nautical miles) 64 kt wind max. NW (nautical miles)  \
# 0                                 -999                                -999
# 1                                 -999                                -999
# 2                                 -999                                -999
# 3                                 -999                                -999
# 4                                 -999                                -999
# ..                                 ...                                 ...
# 21                                   0                                  20
# 22                                   0                                   0
# 23                                   0                                   0
# 24                                   0                                   0
# 25                                   0                                   0
#
#    Basin ATCF Cyclone Number HYear     Name Num. best track entries
# 0     AL                  01  1851  UNNAMED                      14
# 1     AL                  01  1851  UNNAMED                      14
# 2     AL                  01  1851  UNNAMED                      14
# 3     AL                  01  1851  UNNAMED                      14
# 4     AL                  01  1851  UNNAMED                      14
# ..   ...                 ...   ...      ...                     ...
# 21    AL                  31  2020     IOTA                      26
# 22    AL                  31  2020     IOTA                      26
# 23    AL                  31  2020     IOTA                      26
# 24    AL                  31  2020     IOTA                      26
# 25    AL                  31  2020     IOTA                      26
#
# [52717 rows x 25 columns]

# %% [markdown]
# The `()` above are just shorthand for `p["Atlantic-HURDAT2.parquet"].deserialize()`.
#
# We can also just pull bytes or strings from S3:

# %%
p["README.md"].get_as_string()
# Out:
# '# HURDAT2 - Atlantic Hurricane Database\n\nAtlantic hurricane database (HURDAT2) 1851-2020 (6.2MB download)\nThis dataset was provided on 10 June 2021 to include the 2020 best tracks.\n\nThis dataset\n([known as Atlantic HURDAT2](https://www.nhc.noaa.gov/data/hurdat/hurdat2-format-nov2019.pdf))\nhas a comma-delimited, text format with six-hourly information on the location, maximum winds, central pressure,\nand (beginning in 2004) size of all known tropical cyclones and subtropical\ncyclones.  The original HURDAT database has been retired.\n\nDetailed information regarding the\n[Atlantic Hurricane Database Re-analysis Project](http://www.aoml.noaa.gov/hrd/data_sub/re_anal.html)\nis available from the\n[Hurricane Research Division](http://www.aoml.noaa.gov/hrd/).\n\n\n## Source\nhttps://www.nhc.noaa.gov/data/\n\n### Reference\nLandsea, C. W. and J. L. Franklin, 2013: Atlantic Hurricane Database Uncertainty and Presentation of a New Database Format. Mon. Wea. Rev., 141, 3576-3592.\n'

# %% [markdown]
# ## Documenting datasets as Quilt packages
# Data only makes sense in the context of documentation, visualizations, and commit messages. The Quilt data catalog provides all of this for your data sets. Here's the landing page for [examples/hurdat2](https://open.quiltdata.com/b/quilt-example/packages/examples/hurdat2/) (check it out; datasets should be beautiful; Quilt helps).
#
#
# As you've seen above, Quilt allows you to embed READMEs, PDFs, Vega visualizations and more. You can control how your data package looks by adding a `quilt_summarize.json` at the root. This is simply a list of files or Vega visualizations that you wish Quilt to display in the catalog.

# %%
! cat data/quilt_summarize.json
# Out:
# [
#   "Atlantic-HURDAT2.parquet",
#   "external/hurdat2-format-nov2019.pdf"
# ]

# %% [markdown]
# ## Make your own data package with `push`
# Ready to make your own data package? Fill out these variables so that you can push your own package.

# %%
bucket = "s3://YOUR_BUCKET"
pname = "FIRST/LAST" # keep that / in there! packages require a handle with both parts

# %%
p2 = q3.Package()
p2.set_dir(".", "data")
# Out:
# (local Package)
#  └─.quiltignore
#  └─Atlantic-HURDAT2.parquet
#  └─README.md
#  └─external/
#    └─hurdat2-1851-2020-052921.txt
#    └─hurdat2-format-nov2019.pdf
#  └─quilt_summarize.json

# %% [markdown]
# Above we used `set_dir` to capture the contents of "data" into the root of the package. Now we can push it.

# %%
p2.push(pname, bucket, message="Testing quilt3 packages")

# %% [markdown]
# Boom. Now you've created your own immutable package. Anyone with access to the same S3 bucket can interact with this package as follows:

# %%
p3 = q3.Package.browse(pname, bucket)
# Out:
# Downloading manifest: 100%|██████████| 1.62k/1.62k [00:00<00:00, 1.89kB/s]
# Loading manifest: 100%|██████████| 7/7 [00:00<00:00, 7.03k/s]

# %% [markdown]
# > **Note** It's not recommended to push packages that contain a notebook *from the same notebook* as the notebook file is changing, maybe incomplete on disk, and may have a different hash than the bytes pushed.

# %%
! quilt3 install $pname --registry $bucket --dest test-dir

# %% [markdown]
# That's it. **Go thou and make versioned datasets that are reproducibe, discoverable, and trusted with `quilt3` 🤣. To learn more visit [docs.quiltdata.com](https://docs.quiltdata.com).**
